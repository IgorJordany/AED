# %% [markdown]
# # Importando, Visualizando Dados

# %%
import pandas as pd #importando a biblioteca Pandas

# %%
emprego_df = pd.read_csv('./datas/emprego.csv', delimiter=',')

# %%
emprego_df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 15 columns]

# %%
emprego_df = pd.read_csv('./datas/emprego.csv', delimiter=',', index_col=0)

# %%
emprego_df
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ...      ...    ...      ...    ...      ...       ...       ...        ...
# 211        M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 212        M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 213        M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 214        F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 215        M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#       workex  etest_p specialisation  mba_p      status    salary
# sl_no
# 1         No     55.0         Mkt&HR  58.80      Placed  270000.0
# 2        Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 3         No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 4         No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 5         No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ...      ...      ...            ...    ...         ...       ...
# 211       No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 212       No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 213      Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 214       No     70.0         Mkt&HR  60.23      Placed  204000.0
# 215       No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 14 columns]

# %%
professores_df = pd.read_excel('./datas/dados.xlsx')

# %%
professores_df
# Out:
#    codigo          name genero  idade  peso  altura data_de_nascimento  \
# 0       1   Professor 1      M   35.0  70.0    1.68         1975-09-01
# 1       2   Professor 2    NaN   36.0  75.0    1.75         1974-03-22
# 2       3   Professor 3      F    NaN   NaN    1.70         1985-03-23
# 3       4   Professor 4      F   30.0  55.0    1.55         1948-02-10
# 4       5   Professor 5      M    NaN  75.0    1.70                NaT
# 5       6   Professor 6      M   35.0  70.0     NaN         1975-09-01
# 6       7   Professor 7    NaN   36.0  75.0    1.75         1974-03-22
# 7       8   Professor 8      F    NaN   NaN    1.70         1985-03-23
# 8       9   Professor 9      F   30.0  55.0     NaN         1948-02-10
# 9      10  Professor 10      M    NaN  75.0    1.70                NaT
#
#    Titulacao
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN

# %%
professores_df = pd.read_excel('./datas/dados.xlsx', index_col=0)

# %%
professores_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  Titulacao
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01        NaN
# 2        Professor 2    NaN   36.0  75.0    1.75         1974-03-22        NaN
# 3        Professor 3      F    NaN   NaN    1.70         1985-03-23        NaN
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10        NaN
# 5        Professor 5      M    NaN  75.0    1.70                NaT        NaN
# 6        Professor 6      M   35.0  70.0     NaN         1975-09-01        NaN
# 7        Professor 7    NaN   36.0  75.0    1.75         1974-03-22        NaN
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23        NaN
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10        NaN
# 10      Professor 10      M    NaN  75.0    1.70                NaT        NaN

# %%
professores_df.columns
# Out:
# Index(['name', 'genero', 'idade', 'peso', 'altura', 'data_de_nascimento',
#        'Titulacao'],
#       dtype='object')

# %%
professores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 1 to 10
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                10 non-null     object
#  1   genero              8 non-null      object
#  2   idade               6 non-null      float64
#  3   peso                8 non-null      float64
#  4   altura              8 non-null      float64
#  5   data_de_nascimento  8 non-null      datetime64[ns]
#  6   Titulacao           0 non-null      float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 640.0+ bytes

# %%
professores_df.head()
# Out:
#                name genero  idade  peso  altura data_de_nascimento  Titulacao
# codigo
# 1       Professor 1      M   35.0  70.0    1.68         1975-09-01        NaN
# 2       Professor 2    NaN   36.0  75.0    1.75         1974-03-22        NaN
# 3       Professor 3      F    NaN   NaN    1.70         1985-03-23        NaN
# 4       Professor 4      F   30.0  55.0    1.55         1948-02-10        NaN
# 5       Professor 5      M    NaN  75.0    1.70                NaT        NaN

# %%
emprego_df.head()
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#       workex  etest_p specialisation  mba_p      status    salary
# sl_no
# 1         No     55.0         Mkt&HR  58.80      Placed  270000.0
# 2        Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 3         No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 4         No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 5         No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
professores_df.tail()
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  Titulacao
# codigo
# 6        Professor 6      M   35.0  70.0     NaN         1975-09-01        NaN
# 7        Professor 7    NaN   36.0  75.0    1.75         1974-03-22        NaN
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23        NaN
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10        NaN
# 10      Professor 10      M    NaN  75.0    1.70                NaT        NaN

# %%
professores_df['name']
# Out:
# codigo
# 1      Professor 1
# 2      Professor 2
# 3      Professor 3
# 4      Professor 4
# 5      Professor 5
# 6      Professor 6
# 7      Professor 7
# 8      Professor 8
# 9      Professor 9
# 10    Professor 10
# Name: name, dtype: object

# %%
professores_df['genero'].unique()
# Out:
# array(['M', nan, 'F'], dtype=object)

# %%
emprego_df['hsc_s'].unique()
# Out:
# array(['Commerce', 'Science', 'Arts'], dtype=object)

# %% [markdown]
# # Identificando Dados Ausentes

# %%
len(professores_df)
# Out:
# 10

# %%
professores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 1 to 10
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                10 non-null     object
#  1   genero              8 non-null      object
#  2   idade               6 non-null      float64
#  3   peso                8 non-null      float64
#  4   altura              8 non-null      float64
#  5   data_de_nascimento  8 non-null      datetime64[ns]
#  6   Titulacao           0 non-null      float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 640.0+ bytes

# %%
professores_df.isna()
# Out:
#          name  genero  idade   peso  altura  data_de_nascimento  Titulacao
# codigo
# 1       False   False  False  False   False               False       True
# 2       False    True  False  False   False               False       True
# 3       False   False   True   True   False               False       True
# 4       False   False  False  False   False               False       True
# 5       False   False   True  False   False                True       True
# 6       False   False  False  False    True               False       True
# 7       False    True  False  False   False               False       True
# 8       False   False   True   True   False               False       True
# 9       False   False  False  False    True               False       True
# 10      False   False   True  False   False                True       True

# %%
professores_df.notna()
# Out:
#         name  genero  idade   peso  altura  data_de_nascimento  Titulacao
# codigo
# 1       True    True   True   True    True                True      False
# 2       True   False   True   True    True                True      False
# 3       True    True  False  False    True                True      False
# 4       True    True   True   True    True                True      False
# 5       True    True  False   True    True               False      False
# 6       True    True   True   True   False                True      False
# 7       True   False   True   True    True                True      False
# 8       True    True  False  False    True                True      False
# 9       True    True   True   True   False                True      False
# 10      True    True  False   True    True               False      False

# %%
professores_df.isnull()
# Out:
#          name  genero  idade   peso  altura  data_de_nascimento  Titulacao
# codigo
# 1       False   False  False  False   False               False       True
# 2       False    True  False  False   False               False       True
# 3       False   False   True   True   False               False       True
# 4       False   False  False  False   False               False       True
# 5       False   False   True  False   False                True       True
# 6       False   False  False  False    True               False       True
# 7       False    True  False  False   False               False       True
# 8       False   False   True   True   False               False       True
# 9       False   False  False  False    True               False       True
# 10      False   False   True  False   False                True       True

# %%
professores_df.isnull().sum()
# Out:
# name                   0
# genero                 2
# idade                  4
# peso                   2
# altura                 2
# data_de_nascimento     2
# Titulacao             10
# dtype: int64

# %%
professores_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  Titulacao
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01        NaN
# 2        Professor 2    NaN   36.0  75.0    1.75         1974-03-22        NaN
# 3        Professor 3      F    NaN   NaN    1.70         1985-03-23        NaN
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10        NaN
# 5        Professor 5      M    NaN  75.0    1.70                NaT        NaN
# 6        Professor 6      M   35.0  70.0     NaN         1975-09-01        NaN
# 7        Professor 7    NaN   36.0  75.0    1.75         1974-03-22        NaN
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23        NaN
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10        NaN
# 10      Professor 10      M    NaN  75.0    1.70                NaT        NaN

# %%
professores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 1 to 10
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                10 non-null     object
#  1   genero              8 non-null      object
#  2   idade               6 non-null      float64
#  3   peso                8 non-null      float64
#  4   altura              8 non-null      float64
#  5   data_de_nascimento  8 non-null      datetime64[ns]
#  6   Titulacao           0 non-null      float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 640.0+ bytes

# %%
professores_df.describe()
# Out:
#            idade       peso    altura   data_de_nascimento  Titulacao
# count   6.000000   8.000000  8.000000                    8        0.0
# mean   33.666667  68.750000  1.691250  1970-10-21 12:00:00        NaN
# min    30.000000  55.000000  1.550000  1948-02-10 00:00:00        NaN
# 25%    31.250000  66.250000  1.695000  1967-09-10 18:00:00        NaN
# 50%    35.000000  72.500000  1.700000  1974-12-11 00:00:00        NaN
# 75%    35.750000  75.000000  1.712500  1978-01-20 18:00:00        NaN
# max    36.000000  75.000000  1.750000  1985-03-23 00:00:00        NaN
# std     2.875181   8.762746  0.062436                  NaN        NaN

# %% [markdown]
# # Tratando Dados Ausentes

# %%
import pandas as pd
professores2_df = pd.read_excel('./datas/dados_2.xlsx', index_col=0)

# %%
professores2_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN   NaN    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %% [markdown]
# Removendo linhas com dados ausentes

# %%
professores2_df_no_missing = professores2_df.dropna()
professores2_df_no_missing
# Out:
#                name genero  idade  peso  altura data_de_nascimento  Titulacao
# codigo
# 1       Professor 1      M   35.0  70.0    1.68         1975-09-01   Mestrado
# 4       Professor 4      F   30.0  55.0    1.55         1948-02-10  doutorado
# 6       Professor 6      M   35.0  70.0    1.55         1975-09-01  Doutorado

# %% [markdown]
# Muitos dados foram removidos

# %% [markdown]
# Removendo linhas com a maioria dos dados ausentes

# %%
professores2_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN   NaN    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %%
professores2_df_limiar_missing = professores2_df.dropna(thresh=5)
professores2_df_limiar_missing
# Out:
#                name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1       Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2       Professor 2      F   36.0  75.0    1.75         1974-03-22
# 4       Professor 4      F   30.0  55.0    1.55         1948-02-10
# 6       Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7       Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8       Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9       Professor 9      F   30.0  55.0     NaN         1948-02-10
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 4            doutorado
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN

# %%
professores2_df_limiar_missing = professores2_df.dropna(thresh=6)
professores2_df_limiar_missing
# Out:
#                name genero  idade  peso  altura data_de_nascimento  Titulacao
# codigo
# 1       Professor 1      M   35.0  70.0    1.68         1975-09-01   Mestrado
# 2       Professor 2      F   36.0  75.0    1.75         1974-03-22        NaN
# 4       Professor 4      F   30.0  55.0    1.55         1948-02-10  doutorado
# 6       Professor 6      M   35.0  70.0    1.55         1975-09-01  Doutorado
# 7       Professor 7      F   36.0  75.0    1.75         1974-03-22        NaN

# %% [markdown]
# Removendo com colunas com percentual de dados ausentes acima do parâmetro definido

# %%
professores2_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN   NaN    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %%
professores2_df_percentual_columns_missing = professores2_df.dropna(axis=1, thresh=int(0.6*len(professores2_df)))
professores2_df_percentual_columns_missing
# Out:
#                 name genero  idade  peso  altura data_de_nascimento
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN   NaN    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT

# %% [markdown]
# Preenchendo dados ausentes com valores genéricos.

# %%
professores2_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN   NaN    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %%
professores2_df_generic_no_missing = professores2_df.fillna(-1)
professores2_df_generic_no_missing
# Out:
#                 name genero  idade  peso  altura   data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68  1975-09-01 00:00:00
# 2        Professor 2      F   36.0  75.0    1.75  1974-03-22 00:00:00
# 3        Professor 3      M   -1.0  -1.0    1.70  1985-03-23 00:00:00
# 4        Professor 4      F   30.0  55.0    1.55  1948-02-10 00:00:00
# 5        Professor 5      M   -1.0  75.0    1.70                   -1
# 6        Professor 6      M   35.0  70.0    1.55  1975-09-01 00:00:00
# 7        Professor 7      F   36.0  75.0    1.75  1974-03-22 00:00:00
# 8        Professor 8      F   -1.0  -1.0    1.70  1985-03-23 00:00:00
# 9        Professor 9      F   30.0  55.0   -1.00  1948-02-10 00:00:00
# 10      Professor 10      M   -1.0  75.0    1.70                   -1
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                   -1
# 3                   -1
# 4            doutorado
# 5                   -1
# 6            Doutorado
# 7                   -1
# 8       Especialização
# 9                   -1
# 10                  -1

# %% [raw]
# Preenchendo dados ausentes com valores das linhas adjacentes.

# %%
professores2_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN   NaN    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %%
professores2_df_next_value = professores2_df.bfill()  #Utiliza o próximo valor não nulo
professores2_df_next_value
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M   30.0  55.0    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M   35.0  75.0    1.70         1975-09-01
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F   30.0  55.0    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0    1.70         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2            doutorado
# 3            doutorado
# 4            doutorado
# 5            Doutorado
# 6            Doutorado
# 7       Especialização
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %%
professores2_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN   NaN    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %%
professores2_df_forward_value = professores2_df.ffill() #Utiliza o valor anterior não nulo
professores2_df_forward_value
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M   36.0  75.0    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M   30.0  75.0    1.70         1948-02-10
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F   36.0  75.0    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0    1.70         1948-02-10
# 10      Professor 10      M   30.0  75.0    1.70         1948-02-10
#
#              Titulacao
# codigo
# 1             Mestrado
# 2             Mestrado
# 3             Mestrado
# 4            doutorado
# 5            doutorado
# 6            Doutorado
# 7            Doutorado
# 8       Especialização
# 9       Especialização
# 10      Especialização

# %% [markdown]
# Preenchimento de dados ausentes com valores de tendências centrais.

# %%
professores2_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN   NaN    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %%
idade_media = professores2_df['idade'].mean()
altura_media = professores2_df['altura'].mean()
print("Idade Média:", idade_media, " - Altura Média:", altura_media)
# Out:
# Idade Média: 33.666666666666664  - Altura Média: 1.6755555555555555

# %%
dados_preenchimento = {'idade': idade_media, 'altura': altura_media} # Dicionário
dados_preenchimento
# Out:
# {'idade': 33.666666666666664, 'altura': 1.6755555555555555}

# %%
professores2_df_central_tendency=professores2_df.fillna(value=dados_preenchimento)
professores2_df_central_tendency
# Out:
#                 name genero      idade  peso    altura data_de_nascimento  \
# codigo
# 1        Professor 1      M  35.000000  70.0  1.680000         1975-09-01
# 2        Professor 2      F  36.000000  75.0  1.750000         1974-03-22
# 3        Professor 3      M  33.666667   NaN  1.700000         1985-03-23
# 4        Professor 4      F  30.000000  55.0  1.550000         1948-02-10
# 5        Professor 5      M  33.666667  75.0  1.700000                NaT
# 6        Professor 6      M  35.000000  70.0  1.550000         1975-09-01
# 7        Professor 7      F  36.000000  75.0  1.750000         1974-03-22
# 8        Professor 8      F  33.666667   NaN  1.700000         1985-03-23
# 9        Professor 9      F  30.000000  55.0  1.675556         1948-02-10
# 10      Professor 10      M  33.666667  75.0  1.700000                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %% [markdown]
# Preenchimento de dados ausentes baseado em condições.

# %%
professores2_df = pd.read_excel('./datas/dados_2.xlsx', index_col=0)
professores2_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN   NaN    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %%
professores2_df_peso_genero = professores2_df[['genero', 'peso']]

# %%
professores2_df_peso_genero
# Out:
#        genero  peso
# codigo
# 1           M  70.0
# 2           F  75.0
# 3           M   NaN
# 4           F  55.0
# 5           M  75.0
# 6           M  70.0
# 7           F  75.0
# 8           F   NaN
# 9           F  55.0
# 10          M  75.0

# %%
professores2_df_peso_genero.groupby('genero').transform(lambda x: x.fillna(x.mean()))
# Out:
#         peso
# codigo
# 1       70.0
# 2       75.0
# 3       72.5
# 4       55.0
# 5       75.0
# 6       70.0
# 7       75.0
# 8       65.0
# 9       55.0
# 10      75.0

# %%
professores2_df_peso_genero
# Out:
#        genero  peso
# codigo
# 1           M  70.0
# 2           F  75.0
# 3           M  72.5
# 4           F  55.0
# 5           M  75.0
# 6           M  70.0
# 7           F  75.0
# 8           F  65.0
# 9           F  55.0
# 10          M  75.0

# %%
professores2_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN   NaN    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN   NaN    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %%
professores2_df[['peso']] = professores2_df_peso_genero[['peso']]

# %%
professores2_df
# Out:
#                 name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01
# 2        Professor 2      F   36.0  75.0    1.75         1974-03-22
# 3        Professor 3      M    NaN  72.5    1.70         1985-03-23
# 4        Professor 4      F   30.0  55.0    1.55         1948-02-10
# 5        Professor 5      M    NaN  75.0    1.70                NaT
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01
# 7        Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8        Professor 8      F    NaN  65.0    1.70         1985-03-23
# 9        Professor 9      F   30.0  55.0     NaN         1948-02-10
# 10      Professor 10      M    NaN  75.0    1.70                NaT
#
#              Titulacao
# codigo
# 1             Mestrado
# 2                  NaN
# 3                  NaN
# 4            doutorado
# 5                  NaN
# 6            Doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN
# 10                 NaN

# %%
for x in professores2_df.groupby("genero"):
    print("Imprimindo grupo")
    print(x)
    print("\n\n")
# Out:
# Imprimindo grupo
# ('F',                name genero  idade  peso  altura data_de_nascimento  \
# codigo
# 2       Professor 2      F   36.0  75.0    1.75         1974-03-22
# 4       Professor 4      F   30.0  55.0    1.55         1948-02-10
# 7       Professor 7      F   36.0  75.0    1.75         1974-03-22
# 8       Professor 8      F    NaN  65.0    1.70         1985-03-23
# 9       Professor 9      F   30.0  55.0     NaN         1948-02-10
#
#              Titulacao
# codigo
# 2                  NaN
# 4            doutorado
# 7                  NaN
# 8       Especialização
# 9                  NaN  )
#
#
#
# Imprimindo grupo
# ('M',                 name genero  idade  peso  altura data_de_nascimento  Titulacao
# codigo
# 1        Professor 1      M   35.0  70.0    1.68         1975-09-01   Mestrado
# 3        Professor 3      M    NaN  72.5    1.70         1985-03-23        NaN
# 5        Professor 5      M    NaN  75.0    1.70                NaT        NaN
# 6        Professor 6      M   35.0  70.0    1.55         1975-09-01  Doutorado
# 10      Professor 10      M    NaN  75.0    1.70                NaT        NaN)
